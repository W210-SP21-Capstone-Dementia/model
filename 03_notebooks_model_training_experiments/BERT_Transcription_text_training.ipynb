# %%
! python3 -m pip install --upgrade pip
! python3 -m pip install --upgrade SpeechRecognition
! python3 -m pip install --upgrade pydub
! python3 -m pip install --upgrade sklearn
! python3 -m pip install --upgrade pylangacq
# Out:
# Collecting pip
#   Downloading https://files.pythonhosted.org/packages/fe/ef/60d7ba03b5c442309ef42e7d69959f73aacccd0d86008362a681c4698e83/pip-21.0.1-py3-none-any.whl (1.5MB)
#      |████████████████████████████████| 1.5MB 7.4MB/s
# Installing collected packages: pip
#   Found existing installation: pip 19.3.1
#     Uninstalling pip-19.3.1:
#       Successfully uninstalled pip-19.3.1
# Successfully installed pip-21.0.1
# Collecting SpeechRecognition
#   Downloading SpeechRecognition-3.8.1-py2.py3-none-any.whl (32.8 MB)
#      |████████████████████████████████| 32.8 MB 61 kB/s
# Installing collected packages: SpeechRecognition
# Successfully installed SpeechRecognition-3.8.1
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.0.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.19.5)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.4.1)
# Collecting pylangacq
#   Downloading pylangacq-0.13.1-py3-none-any.whl (66 kB)
#      |████████████████████████████████| 66 kB 3.2 MB/s
# Requirement already satisfied: requests<=3.0.0,>=2.18.0 in /usr/local/lib/python3.7/dist-packages (from pylangacq) (2.23.0)
# Requirement already satisfied: python-dateutil<=3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from pylangacq) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil<=3.0.0,>=2.0.0->pylangacq) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<=3.0.0,>=2.18.0->pylangacq) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<=3.0.0,>=2.18.0->pylangacq) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<=3.0.0,>=2.18.0->pylangacq) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<=3.0.0,>=2.18.0->pylangacq) (1.24.3)
# Installing collected packages: pylangacq
# Successfully installed pylangacq-0.13.1

# %%
import IPython.display as ipd
import librosa
import librosa.display
import kapre
import matplotlib.pyplot as plt
import numpy as np
import pathlib
import io
import os
import pandas as pd
import random
import re
import shutil
import speech_recognition as sr
import tensorflow as tf
from os import listdir
from os.path import isfile, join
from os import path
from plotnine import *
from pydub import AudioSegment
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier, StackingClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from pydub.silence import split_on_silence 

# Cloud storage
from google.cloud import storage

# .cha file reader
import pylangacq

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Transcribe audio data to txt data

# %%
# !ls '/content/drive/My Drive/Berkeley/W210/Capstone/ADReSS-IS2020-data/train/Full_wave_enhanced_audio/cd/'

# %%
# initialize the speech recognizer
r = sr.Recognizer()

# a function that splits the audio file into chunks 
# and applies speech recognition 
def silence_based_conversion(path, wav_file): 
    text_df = pd.DataFrame()
  
    # open the audio file stored in 
    # the local system as a wav file. 
    song = AudioSegment.from_wav(path + wav_file) 
    print(song)
  
    # open a file where we will concatenate   
    # and store the recognized text 
    text_file = wav_file.partition('.')[0] + ".txt"
    text_file_dir = path + "output_text/" 
    if not os.path.exists(text_file_dir):
        os.makedirs(text_file_dir)    
    text_file_path = text_file_dir + text_file
    fh = open(text_file_path, "w+") 
          

    dBFS = song.dBFS
    print('dBFS: ' + str(dBFS))
    # chunks = split_on_silence(song, 
    #     min_silence_len = 500,
    #     silence_thresh = dBFS-16,
    #     keep_silence = 250 
    # )

    # split track where silence is 0.5 seconds  
    # or more and get chunks 
    chunks = split_on_silence(song, 
        # must be silent for at least 0.5 seconds 
        # or 500 ms. adjust this value based on user 
        # requirement. if the speaker stays silent for  
        # longer, increase this value. else, decrease it. 
        min_silence_len = 250, 
  
        # consider it silent if quieter than -16 dBFS 
        # adjust this per requirement 
        silence_thresh = dBFS - 16
        # keep_silence = 250
    ) 
    # setting minimum length of each chunk to 25 seconds
    target_length = 20 * 1000 
    output_chunks = [chunks[0]]
    for chunk in chunks[1:]:
      print('Length of chunk: ' + str(len(output_chunks[-1])) )
      if len(output_chunks[-1]) < target_length:
        output_chunks[-1] += chunk
      else:
        # if the last output chunk is longer than the target length,
        # we can start a new one
        output_chunks.append(chunk)    
    # print(chunks)
  
    # create a directory to store the audio chunks. 
    try: 
        os.mkdir(path + 'audio_chunks') 
    except(FileExistsError): 
        pass
  
    # move into the directory to 
    # store the audio files. 
    os.chdir(path +'audio_chunks') 
  
    i = 0
    # process each chunk 
    for chunk in output_chunks: 
              
        # Create 0.5 seconds silence chunk 
        chunk_silent = AudioSegment.silent(duration = 10) 
  
        # add 0.5 sec silence to beginning and  
        # end of audio chunk. This is done so that 
        # it doesn't seem abruptly sliced. 
        audio_chunk = chunk_silent + chunk + chunk_silent 
  
        # export audio chunk and save it in  
        # the current directory. 
        text_file_id = text_file.partition('.')[0]
        chunk_file_name = text_file_id + "_" + "chunk" + str(i) + ".wav"
        print("saving " + chunk_file_name) 
        # specify the bitrate to be 192 k 
        audio_chunk.export("./" + chunk_file_name, bitrate ='192k', format ="wav") 
  
        # the name of the newly created chunk 
        filename = chunk_file_name
  
        print("Processing chunk file: " + filename) 
  
        # get the name of the newly created chunk 
        # in the AUDIO_FILE variable for later use. 
        file = filename 
  
        # create a speech recognition object 
        r = sr.Recognizer() 
  
        # recognize the chunk 
        with sr.AudioFile(file) as source: 
            # remove this if it is not working 
            # correctly. 
            #r.adjust_for_ambient_noise(source) 
            audio_listened = r.record(source) 
  
        try: 
            # try converting it to text 
            rec = r.recognize_google(audio_listened) 
            # write the output to the file. 
            fh.write(rec+". ") 
            text_df = text_df.append({'ID': text_file_id, 'Text': rec}, ignore_index = True)
  
        # catch any errors. 
        except sr.UnknownValueError: 
            print("Could not understand audio") 
  
        except sr.RequestError as e: 
            print("Could not request results. check your internet connection") 
  
        i += 1
    return text_df

# silence_based_conversion(audio_path_cc, 'S001.wav')        
# text_df = silence_based_conversion(audio_path_cd, 'S079.wav')        
# print(text_df)
# silence_based_conversion(audio_path_cc + 'spkr0.wav')

# %% [markdown]
# ## Read csv data file with ID, TEXT and MMSE scores to be used for training and validation

# %%
data_path = '/content/drive/My Drive/Berkeley/W210/Capstone/ADReSS-IS2020-data/train'

transcription_combination_txt_file_path = data_path + "/transcription_shuffled_text/" + "transcription_combination_id_txt_mmse.csv"
filtered_merged_data = pd.read_csv(transcription_combination_txt_file_path)
filtered_merged_data.tail()
# Out:
#       Unnamed: 0    ID  ...  MMSE Group
# 1395        1395  S156  ...    13    cd
# 1396        1396  S156  ...    13    cd
# 1397        1397  S156  ...    13    cd
# 1398        1398  S156  ...    13    cd
# 1399        1399  S156  ...    13    cd
#
# [5 rows x 7 columns]

# %% [markdown]
# # BERT Transfer Learning

# %%
# !pip install transformers==3.0.2
# Out:
# Collecting transformers==3.0.2
#   Downloading transformers-3.0.2-py3-none-any.whl (769 kB)
#      |████████████████████████████████| 769 kB 8.5 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.2) (3.0.12)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.2) (4.41.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.2) (2.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.2) (2019.12.20)
# Collecting sacremoses
#   Downloading sacremoses-0.0.43.tar.gz (883 kB)
#      |████████████████████████████████| 883 kB 10.4 MB/s
# Collecting tokenizers==0.8.1.rc1
#   Downloading tokenizers-0.8.1rc1-cp37-cp37m-manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 33.0 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.2) (20.9)
# Collecting sentencepiece!=0.1.92
#   Downloading sentencepiece-0.1.95-cp37-cp37m-manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 37.6 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.2) (1.19.5)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==3.0.2) (2.4.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.0.2) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.0.2) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.0.2) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.0.2) (2.10)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.0.2) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.0.2) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.0.2) (1.0.1)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-py3-none-any.whl size=893258 sha256=46fdaec3e66a91e455992aabd4075b46b5bfd6c99e9c63464db33ce2fe50cf38
#   Stored in directory: /root/.cache/pip/wheels/69/09/d1/bf058f7d6fa0ecba2ce7c66be3b8d012beb4bf61a6e0c101c0
# Successfully built sacremoses
# Installing collected packages: tokenizers, sentencepiece, sacremoses, transformers
# Successfully installed sacremoses-0.0.43 sentencepiece-0.1.95 tokenizers-0.8.1rc1 transformers-3.0.2

# %%
from transformers import BertTokenizer
bert_name = 'bert-base-uncased'
tokenizer = BertTokenizer.from_pretrained(bert_name,
                                          add_special_tokens=True,
                                          do_lower_case=True,
                                          max_length=256,
                                          pad_to_max_length=True)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…

# %%
def bert_encoder(input_text):
    # txt = input_text.numpy().decode('utf-8')
    txt = input_text
    encoded = tokenizer.encode_plus(txt, add_special_tokens=True, 
                                    max_length=256, 
                                    pad_to_max_length=True, 
                                    return_attention_mask=True, 
                                    return_token_type_ids=True,
                                    truncation=True)
    return encoded['input_ids'], encoded['token_type_ids'], \
           encoded['attention_mask']

# %%
bert_train = [bert_encoder(r) for r in filtered_merged_data["TEXT"]]
bert_lbl = filtered_merged_data["MMSE"]
bert_train = np.array(bert_train)
# bert_lbl = tf.keras.utils.to_categorical(bert_lbl)

# %%
# create training and validation splits
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(bert_train, 
                                         bert_lbl,
                                         test_size=0.2, 
                                         random_state=42)
print(x_train.shape, y_train.shape)
print(x_val.shape, y_val.shape)
# Out:
# (1120, 3, 256) (1120,)
# (280, 3, 256) (280,)

# %%
tr_reviews, tr_segments, tr_masks = np.split(x_train, 3, axis=1)
val_reviews, val_segments, val_masks = np.split(x_val, 3, axis=1)
tr_reviews = tr_reviews.squeeze()
tr_segments = tr_segments.squeeze()
tr_masks = tr_masks.squeeze()
val_reviews = val_reviews.squeeze()
val_segments = val_segments.squeeze()
val_masks = val_masks.squeeze()

# %%
def example_to_features(input_ids,attention_masks,token_type_ids,y):
  return {"input_ids": input_ids,
          "attention_mask": attention_masks,
          "token_type_ids": token_type_ids},y

# %%
train_ds = tf.data.Dataset.from_tensor_slices((tr_reviews, 
tr_masks, tr_segments, y_train)).\
            map(example_to_features).shuffle(100).batch(16)
valid_ds = tf.data.Dataset.from_tensor_slices((val_reviews, 
val_masks, val_segments, y_val)).\
            map(example_to_features).shuffle(100).batch(16)

# %%
train_ds
# Out:
# <BatchDataset shapes: ({input_ids: (None, 256), attention_mask: (None, 256), token_type_ids: (None, 256)}, (None,)), types: ({input_ids: tf.int64, attention_mask: tf.int64, token_type_ids: tf.int64}, tf.int64)>

# %%
# from transformers import TFBertForSequenceClassification
# bert_model = TFBertForSequenceClassification.from_pretrained(bert_name, num_labels=31)

# %%
# # optimizer = tf.keras.optimizers.Adam(learning_rate=2e-5)

# # loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, name="sparse_categorical_crossentropy")
# # loss = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
# # metrics = tf.metrics.CategoricalCrossentropy()
# # bert_model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])
# optimizer = tf.compat.v1.train.GradientDescentOptimizer(learning_rate=2e-5)
# bert_model.compile(optimizer = optimizer, 
#                    loss=tf.keras.metrics.mean_squared_error,
#                    metrics=[tf.keras.metrics.RootMeanSquaredError(name='rmse')])

# %%
# print("Fine-tuning BERT on Training data")
# bert_history = bert_model.fit(train_ds, epochs=25, 
#                               validation_data=valid_ds)

# %%
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Model

def build_model(transformer, max_len=512):
    """
    https://www.kaggle.com/xhlulu/jigsaw-tpu-distilbert-with-huggingface-and-keras
    """
    input_word_ids = Input(shape=(max_len,), dtype=tf.int32, name="input_ids")
    sequence_output = transformer(input_word_ids)[0]
    cls_token = sequence_output[:, 0, :]
    out = Dense(1, activation='relu')(cls_token)
#     run_opts = tf.RunOptions(report_tensor_allocations_upon_oom = True)
    model = Model(inputs=input_word_ids, outputs=out)
    for layer in model.layers[:-1]:
      layer.trainable = False
    # model.compile(Adam(lr=1e-5), loss='binary_crossentropy', metrics=['accuracy']) #, options = run_opts)
    # optimizer = tf.compat.v1.train.GradientDescentOptimizer(learning_rate=2e-5)
    optimizer = tf.keras.optimizers.Adam(learning_rate=2e-5)
    model.compile(optimizer = optimizer, 
                  loss=tf.keras.metrics.mean_squared_error,
                  metrics=[tf.keras.metrics.RootMeanSquaredError(name='rmse')])
    return model

# %%
import transformers
MAX_LEN = 256
# with strategy.scope():
def create_model():
  transformer_layer = (
      transformers.TFAutoModelWithLMHead.from_pretrained(bert_name)
  )
  model = build_model(transformer_layer, max_len=MAX_LEN)
  return model

# %%
model = create_model()
model.summary()
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing TFBertForMaskedLM: ['nsp___cls']
# - This IS expected if you are initializing TFBertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing TFBertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertForMaskedLM were initialized from the model checkpoint at bert-base-uncased.
# If your task is similar to the task the model of the ckeckpoint was trained on, you can already use TFBertForMaskedLM for predictions without further training.
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_ids (InputLayer)       [(None, 256)]             0
# _________________________________________________________________
# tf_bert_for_masked_lm_2 (TFB ((None, 256, 30522),)     110104890
# _________________________________________________________________
# tf.__operators__.getitem_2 ( (None, 30522)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 30523
# =================================================================
# Total params: 110,135,413
# Trainable params: 30,523
# Non-trainable params: 110,104,890
# _________________________________________________________________

# %%
checkpoint_path = "/content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 monitor='val_loss', 
                                                 patience=50, 
                                                 restore_best_weights=True,
                                                 verbose=1)

# es_callback = tf.keras.callbacks.EarlyStopping(
#     monitor='val_loss', 
#     patience=50, 
#     restore_best_weights=True)

print("Fine-tuning BERT on Training data")
bert_history = model.fit(train_ds, 
                         epochs=1000, 
                         validation_data=valid_ds,
                         callbacks=[cp_callback])
# Out:
# Fine-tuning BERT on Training data
# Epoch 1/1000
# 70/70 [==============================] - 12s 165ms/step - loss: 44.1184 - rmse: 6.6422 - val_loss: 43.1839 - val_rmse: 6.5714
#
# Epoch 00001: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 2/1000
# 70/70 [==============================] - 12s 165ms/step - loss: 43.3296 - rmse: 6.5825 - val_loss: 42.7506 - val_rmse: 6.5384
#
# Epoch 00002: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 3/1000
# 70/70 [==============================] - 12s 165ms/step - loss: 42.9985 - rmse: 6.5573 - val_loss: 37.1734 - val_rmse: 6.0970
#
# Epoch 00003: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 4/1000
# 70/70 [==============================] - 12s 166ms/step - loss: 42.3397 - rmse: 6.5069 - val_loss: 36.9305 - val_rmse: 6.0770
#
# Epoch 00004: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 5/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 42.2656 - rmse: 6.5012 - val_loss: 36.6950 - val_rmse: 6.0576
#
# Epoch 00005: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 6/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 42.1564 - rmse: 6.4928 - val_loss: 34.9732 - val_rmse: 5.9138
#
# Epoch 00006: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 7/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 41.5227 - rmse: 6.4438 - val_loss: 35.5327 - val_rmse: 5.9609
#
# Epoch 00007: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 8/1000
# 70/70 [==============================] - 12s 166ms/step - loss: 41.4943 - rmse: 6.4416 - val_loss: 34.1407 - val_rmse: 5.8430
#
# Epoch 00008: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 9/1000
# 70/70 [==============================] - 12s 166ms/step - loss: 39.3081 - rmse: 6.2696 - val_loss: 34.1427 - val_rmse: 5.8432
#
# Epoch 00009: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 10/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 39.1077 - rmse: 6.2536 - val_loss: 37.9977 - val_rmse: 6.1642
#
# Epoch 00010: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 11/1000
# 70/70 [==============================] - 12s 166ms/step - loss: 39.8363 - rmse: 6.3116 - val_loss: 34.6025 - val_rmse: 5.8824
#
# Epoch 00011: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 12/1000
# 70/70 [==============================] - 12s 166ms/step - loss: 38.7801 - rmse: 6.2274 - val_loss: 32.5720 - val_rmse: 5.7072
#
# Epoch 00012: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 13/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 37.6805 - rmse: 6.1384 - val_loss: 38.5829 - val_rmse: 6.2115
#
# Epoch 00013: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 14/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 39.8304 - rmse: 6.3111 - val_loss: 31.8477 - val_rmse: 5.6434
#
# Epoch 00014: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 15/1000
# 70/70 [==============================] - 12s 166ms/step - loss: 38.6837 - rmse: 6.2196 - val_loss: 33.2393 - val_rmse: 5.7654
#
# Epoch 00015: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 16/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 40.1439 - rmse: 6.3359 - val_loss: 34.6279 - val_rmse: 5.8845
#
# Epoch 00016: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 17/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 40.2320 - rmse: 6.3429 - val_loss: 33.7895 - val_rmse: 5.8129
#
# Epoch 00017: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 18/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 38.5442 - rmse: 6.2084 - val_loss: 31.9580 - val_rmse: 5.6531
#
# Epoch 00018: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 19/1000
# 70/70 [==============================] - 12s 166ms/step - loss: 38.2095 - rmse: 6.1814 - val_loss: 30.3350 - val_rmse: 5.5077
#
# Epoch 00019: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 20/1000
# 70/70 [==============================] - 12s 166ms/step - loss: 38.1923 - rmse: 6.1800 - val_loss: 34.5142 - val_rmse: 5.8749
#
# Epoch 00020: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 21/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 37.2103 - rmse: 6.1000 - val_loss: 30.1313 - val_rmse: 5.4892
#
# Epoch 00021: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 22/1000
# 70/70 [==============================] - 12s 166ms/step - loss: 36.3063 - rmse: 6.0255 - val_loss: 30.5217 - val_rmse: 5.5246
#
# Epoch 00022: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 23/1000
# 70/70 [==============================] - 12s 165ms/step - loss: 37.4129 - rmse: 6.1166 - val_loss: 31.7664 - val_rmse: 5.6362
#
# Epoch 00023: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 24/1000
# 70/70 [==============================] - 12s 166ms/step - loss: 37.5273 - rmse: 6.1260 - val_loss: 30.5653 - val_rmse: 5.5286
#
# Epoch 00024: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 25/1000
# 70/70 [==============================] - 12s 166ms/step - loss: 37.5174 - rmse: 6.1251 - val_loss: 29.9316 - val_rmse: 5.4710
#
# Epoch 00025: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 26/1000
# 70/70 [==============================] - 12s 166ms/step - loss: 36.3387 - rmse: 6.0282 - val_loss: 30.5769 - val_rmse: 5.5296
#
# Epoch 00026: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 27/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 36.9489 - rmse: 6.0786 - val_loss: 29.4898 - val_rmse: 5.4305
#
# Epoch 00027: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 28/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 37.6413 - rmse: 6.1352 - val_loss: 29.3355 - val_rmse: 5.4162
#
# Epoch 00028: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 29/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 37.7659 - rmse: 6.1454 - val_loss: 32.2821 - val_rmse: 5.6817
#
# Epoch 00029: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 30/1000
# 70/70 [==============================] - 12s 166ms/step - loss: 36.6335 - rmse: 6.0526 - val_loss: 30.3543 - val_rmse: 5.5095
#
# Epoch 00030: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 31/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 37.1358 - rmse: 6.0939 - val_loss: 29.4924 - val_rmse: 5.4307
#
# Epoch 00031: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 32/1000
# 70/70 [==============================] - 12s 165ms/step - loss: 36.7491 - rmse: 6.0621 - val_loss: 28.0779 - val_rmse: 5.2989
#
# Epoch 00032: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 33/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 37.1900 - rmse: 6.0984 - val_loss: 29.5712 - val_rmse: 5.4379
#
# Epoch 00033: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 34/1000
# 70/70 [==============================] - 12s 166ms/step - loss: 35.1019 - rmse: 5.9247 - val_loss: 29.7737 - val_rmse: 5.4565
#
# Epoch 00034: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 35/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 35.5194 - rmse: 5.9598 - val_loss: 28.0916 - val_rmse: 5.3002
#
# Epoch 00035: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 36/1000
# 70/70 [==============================] - 12s 166ms/step - loss: 35.9196 - rmse: 5.9933 - val_loss: 28.3092 - val_rmse: 5.3206
#
# Epoch 00036: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 37/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 36.0260 - rmse: 6.0022 - val_loss: 28.5304 - val_rmse: 5.3414
#
# Epoch 00037: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 38/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 35.0450 - rmse: 5.9199 - val_loss: 28.5864 - val_rmse: 5.3466
#
# Epoch 00038: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 39/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 37.8203 - rmse: 6.1498 - val_loss: 30.8447 - val_rmse: 5.5538
#
# Epoch 00039: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 40/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 35.0967 - rmse: 5.9242 - val_loss: 28.5272 - val_rmse: 5.3411
#
# Epoch 00040: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 41/1000
# 70/70 [==============================] - 12s 166ms/step - loss: 34.2847 - rmse: 5.8553 - val_loss: 28.5174 - val_rmse: 5.3402
#
# Epoch 00041: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 42/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 35.6716 - rmse: 5.9726 - val_loss: 29.8048 - val_rmse: 5.4594
#
# Epoch 00042: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 43/1000
# 70/70 [==============================] - 12s 166ms/step - loss: 34.7801 - rmse: 5.8975 - val_loss: 30.3767 - val_rmse: 5.5115
#
# Epoch 00043: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 44/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 37.3758 - rmse: 6.1136 - val_loss: 28.0854 - val_rmse: 5.2996
#
# Epoch 00044: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 45/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 36.3630 - rmse: 6.0302 - val_loss: 32.6091 - val_rmse: 5.7104
#
# Epoch 00045: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 46/1000
# 70/70 [==============================] - 12s 166ms/step - loss: 37.0899 - rmse: 6.0901 - val_loss: 27.0250 - val_rmse: 5.1986
#
# Epoch 00046: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 47/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 33.8888 - rmse: 5.8214 - val_loss: 27.3221 - val_rmse: 5.2271
#
# Epoch 00047: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 48/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 36.5222 - rmse: 6.0434 - val_loss: 27.9195 - val_rmse: 5.2839
#
# Epoch 00048: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 49/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 34.7108 - rmse: 5.8916 - val_loss: 26.6120 - val_rmse: 5.1587
#
# Epoch 00049: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 50/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 34.1293 - rmse: 5.8420 - val_loss: 27.1886 - val_rmse: 5.2143
#
# Epoch 00050: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 51/1000
# 70/70 [==============================] - 12s 165ms/step - loss: 34.9039 - rmse: 5.9080 - val_loss: 26.6589 - val_rmse: 5.1632
#
# Epoch 00051: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 52/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 33.8436 - rmse: 5.8175 - val_loss: 27.1083 - val_rmse: 5.2066
#
# Epoch 00052: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 53/1000
# 70/70 [==============================] - 12s 166ms/step - loss: 34.6572 - rmse: 5.8870 - val_loss: 27.6807 - val_rmse: 5.2612
#
# Epoch 00053: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 54/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 34.8692 - rmse: 5.9050 - val_loss: 26.7811 - val_rmse: 5.1751
#
# Epoch 00054: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 55/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 33.9266 - rmse: 5.8247 - val_loss: 25.9353 - val_rmse: 5.0927
#
# Epoch 00055: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 56/1000
# 70/70 [==============================] - 12s 166ms/step - loss: 34.0830 - rmse: 5.8381 - val_loss: 26.7250 - val_rmse: 5.1696
#
# Epoch 00056: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 57/1000
# 70/70 [==============================] - 12s 166ms/step - loss: 36.4151 - rmse: 6.0345 - val_loss: 26.0347 - val_rmse: 5.1024
#
# Epoch 00057: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 58/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 35.0308 - rmse: 5.9187 - val_loss: 26.5455 - val_rmse: 5.1522
#
# Epoch 00058: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 59/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 34.6077 - rmse: 5.8828 - val_loss: 25.8918 - val_rmse: 5.0884
#
# Epoch 00059: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 60/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 35.9367 - rmse: 5.9947 - val_loss: 28.0028 - val_rmse: 5.2918
#
# Epoch 00060: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 61/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 34.3347 - rmse: 5.8596 - val_loss: 27.1347 - val_rmse: 5.2091
#
# Epoch 00061: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 62/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 33.4979 - rmse: 5.7877 - val_loss: 26.8250 - val_rmse: 5.1793
#
# Epoch 00062: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 63/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 34.6758 - rmse: 5.8886 - val_loss: 26.3886 - val_rmse: 5.1370
#
# Epoch 00063: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 64/1000
# 70/70 [==============================] - 12s 166ms/step - loss: 34.3632 - rmse: 5.8620 - val_loss: 27.6072 - val_rmse: 5.2543
#
# Epoch 00064: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 65/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 33.7718 - rmse: 5.8114 - val_loss: 29.5142 - val_rmse: 5.4327
#
# Epoch 00065: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 66/1000
# 70/70 [==============================] - 12s 166ms/step - loss: 33.1062 - rmse: 5.7538 - val_loss: 27.5343 - val_rmse: 5.2473
#
# Epoch 00066: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 67/1000
# 70/70 [==============================] - 12s 166ms/step - loss: 33.3920 - rmse: 5.7786 - val_loss: 26.1475 - val_rmse: 5.1135
#
# Epoch 00067: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 68/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 35.0560 - rmse: 5.9208 - val_loss: 26.8983 - val_rmse: 5.1864
#
# Epoch 00068: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 69/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 34.2676 - rmse: 5.8539 - val_loss: 27.3526 - val_rmse: 5.2300
#
# Epoch 00069: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 70/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 33.0159 - rmse: 5.7459 - val_loss: 29.5636 - val_rmse: 5.4372
#
# Epoch 00070: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 71/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 32.6796 - rmse: 5.7166 - val_loss: 27.2473 - val_rmse: 5.2199
#
# Epoch 00071: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 72/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 34.7344 - rmse: 5.8936 - val_loss: 26.9047 - val_rmse: 5.1870
#
# Epoch 00072: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 73/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 32.9373 - rmse: 5.7391 - val_loss: 28.2875 - val_rmse: 5.3186
#
# Epoch 00073: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 74/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 32.8687 - rmse: 5.7331 - val_loss: 26.7133 - val_rmse: 5.1685
#
# Epoch 00074: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 75/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 35.2322 - rmse: 5.9357 - val_loss: 26.2425 - val_rmse: 5.1227
#
# Epoch 00075: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 76/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 34.2999 - rmse: 5.8566 - val_loss: 29.9187 - val_rmse: 5.4698
#
# Epoch 00076: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 77/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 32.7738 - rmse: 5.7248 - val_loss: 27.7522 - val_rmse: 5.2680
#
# Epoch 00077: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 78/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 33.4987 - rmse: 5.7878 - val_loss: 26.2216 - val_rmse: 5.1207
#
# Epoch 00078: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 79/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 32.2336 - rmse: 5.6775 - val_loss: 31.5597 - val_rmse: 5.6178
#
# Epoch 00079: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 80/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 32.2363 - rmse: 5.6777 - val_loss: 25.9125 - val_rmse: 5.0904
#
# Epoch 00080: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 81/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 33.9503 - rmse: 5.8267 - val_loss: 26.5807 - val_rmse: 5.1556
#
# Epoch 00081: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 82/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 34.5072 - rmse: 5.8743 - val_loss: 31.7522 - val_rmse: 5.6349
#
# Epoch 00082: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 83/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 31.2927 - rmse: 5.5940 - val_loss: 32.5377 - val_rmse: 5.7042
#
# Epoch 00083: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 84/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 31.8033 - rmse: 5.6394 - val_loss: 25.1937 - val_rmse: 5.0193
#
# Epoch 00084: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 85/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 32.1666 - rmse: 5.6716 - val_loss: 26.4048 - val_rmse: 5.1386
#
# Epoch 00085: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 86/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 32.4230 - rmse: 5.6941 - val_loss: 25.2949 - val_rmse: 5.0294
#
# Epoch 00086: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 87/1000
# 70/70 [==============================] - 12s 166ms/step - loss: 33.0270 - rmse: 5.7469 - val_loss: 26.5578 - val_rmse: 5.1534
#
# Epoch 00087: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 88/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 31.4385 - rmse: 5.6070 - val_loss: 26.1879 - val_rmse: 5.1174
#
# Epoch 00088: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 89/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 33.5027 - rmse: 5.7882 - val_loss: 27.3539 - val_rmse: 5.2301
#
# Epoch 00089: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 90/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 33.1281 - rmse: 5.7557 - val_loss: 26.3694 - val_rmse: 5.1351
#
# Epoch 00090: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 91/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 33.4144 - rmse: 5.7805 - val_loss: 28.9516 - val_rmse: 5.3807
#
# Epoch 00091: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 92/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 32.7726 - rmse: 5.7247 - val_loss: 27.3793 - val_rmse: 5.2325
#
# Epoch 00092: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 93/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 32.8196 - rmse: 5.7288 - val_loss: 26.9235 - val_rmse: 5.1888
#
# Epoch 00093: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 94/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 33.7318 - rmse: 5.8079 - val_loss: 26.8777 - val_rmse: 5.1844
#
# Epoch 00094: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 95/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 33.9972 - rmse: 5.8307 - val_loss: 27.8495 - val_rmse: 5.2773
#
# Epoch 00095: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 96/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 31.4960 - rmse: 5.6121 - val_loss: 30.3474 - val_rmse: 5.5088
#
# Epoch 00096: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 97/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 33.9837 - rmse: 5.8295 - val_loss: 28.2976 - val_rmse: 5.3195
#
# Epoch 00097: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 98/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 33.0409 - rmse: 5.7481 - val_loss: 27.1672 - val_rmse: 5.2122
#
# Epoch 00098: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 99/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 31.7276 - rmse: 5.6327 - val_loss: 27.4717 - val_rmse: 5.2413
#
# Epoch 00099: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 100/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 32.5117 - rmse: 5.7019 - val_loss: 25.8584 - val_rmse: 5.0851
#
# Epoch 00100: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 101/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 33.3029 - rmse: 5.7709 - val_loss: 26.2736 - val_rmse: 5.1258
#
# Epoch 00101: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 102/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 33.1982 - rmse: 5.7618 - val_loss: 25.8118 - val_rmse: 5.0805
#
# Epoch 00102: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 103/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 32.7704 - rmse: 5.7245 - val_loss: 25.9244 - val_rmse: 5.0916
#
# Epoch 00103: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 104/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 33.0274 - rmse: 5.7469 - val_loss: 26.7892 - val_rmse: 5.1758
#
# Epoch 00104: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 105/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 33.1643 - rmse: 5.7588 - val_loss: 27.3200 - val_rmse: 5.2269
#
# Epoch 00105: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 106/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 31.9975 - rmse: 5.6566 - val_loss: 25.2187 - val_rmse: 5.0218
#
# Epoch 00106: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 107/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 32.2628 - rmse: 5.6800 - val_loss: 25.0965 - val_rmse: 5.0096
#
# Epoch 00107: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 108/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 32.6641 - rmse: 5.7152 - val_loss: 24.7071 - val_rmse: 4.9706
#
# Epoch 00108: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 109/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 32.4479 - rmse: 5.6963 - val_loss: 24.4131 - val_rmse: 4.9410
#
# Epoch 00109: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 110/1000
# 70/70 [==============================] - 12s 170ms/step - loss: 31.1773 - rmse: 5.5837 - val_loss: 33.7674 - val_rmse: 5.8110
#
# Epoch 00110: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 111/1000
# 70/70 [==============================] - 12s 170ms/step - loss: 33.9014 - rmse: 5.8225 - val_loss: 23.3000 - val_rmse: 4.8270
#
# Epoch 00111: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 112/1000
# 70/70 [==============================] - 12s 170ms/step - loss: 33.8007 - rmse: 5.8138 - val_loss: 30.1729 - val_rmse: 5.4930
#
# Epoch 00112: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 113/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 34.0409 - rmse: 5.8345 - val_loss: 26.9121 - val_rmse: 5.1877
#
# Epoch 00113: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 114/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 30.6955 - rmse: 5.5403 - val_loss: 23.6982 - val_rmse: 4.8681
#
# Epoch 00114: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 115/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 31.6281 - rmse: 5.6239 - val_loss: 24.2869 - val_rmse: 4.9282
#
# Epoch 00115: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 116/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 32.7580 - rmse: 5.7235 - val_loss: 24.1111 - val_rmse: 4.9103
#
# Epoch 00116: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 117/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 31.2607 - rmse: 5.5911 - val_loss: 23.9962 - val_rmse: 4.8986
#
# Epoch 00117: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 118/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 32.3568 - rmse: 5.6883 - val_loss: 24.0820 - val_rmse: 4.9073
#
# Epoch 00118: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 119/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 32.1807 - rmse: 5.6728 - val_loss: 24.6873 - val_rmse: 4.9686
#
# Epoch 00119: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 120/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 31.3340 - rmse: 5.5977 - val_loss: 25.0424 - val_rmse: 5.0042
#
# Epoch 00120: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 121/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 31.2544 - rmse: 5.5906 - val_loss: 29.8477 - val_rmse: 5.4633
#
# Epoch 00121: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 122/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 32.4542 - rmse: 5.6969 - val_loss: 24.9804 - val_rmse: 4.9980
#
# Epoch 00122: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 123/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 32.4432 - rmse: 5.6959 - val_loss: 24.8709 - val_rmse: 4.9871
#
# Epoch 00123: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 124/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 32.6393 - rmse: 5.7131 - val_loss: 25.1729 - val_rmse: 5.0173
#
# Epoch 00124: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 125/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 32.1437 - rmse: 5.6695 - val_loss: 24.2754 - val_rmse: 4.9270
#
# Epoch 00125: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 126/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 30.9306 - rmse: 5.5615 - val_loss: 25.9934 - val_rmse: 5.0984
#
# Epoch 00126: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 127/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 31.0040 - rmse: 5.5681 - val_loss: 25.7391 - val_rmse: 5.0734
#
# Epoch 00127: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 128/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 31.5044 - rmse: 5.6129 - val_loss: 26.3694 - val_rmse: 5.1351
#
# Epoch 00128: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 129/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 32.1360 - rmse: 5.6689 - val_loss: 25.4590 - val_rmse: 5.0457
#
# Epoch 00129: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 130/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 32.2012 - rmse: 5.6746 - val_loss: 24.7962 - val_rmse: 4.9796
#
# Epoch 00130: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 131/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 31.1548 - rmse: 5.5817 - val_loss: 25.7928 - val_rmse: 5.0787
#
# Epoch 00131: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 132/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 29.3526 - rmse: 5.4178 - val_loss: 27.8470 - val_rmse: 5.2770
#
# Epoch 00132: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 133/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 31.0846 - rmse: 5.5754 - val_loss: 25.4034 - val_rmse: 5.0402
#
# Epoch 00133: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 134/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 31.9521 - rmse: 5.6526 - val_loss: 25.7761 - val_rmse: 5.0770
#
# Epoch 00134: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 135/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 31.3696 - rmse: 5.6009 - val_loss: 26.8151 - val_rmse: 5.1783
#
# Epoch 00135: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 136/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 32.5524 - rmse: 5.7055 - val_loss: 23.6130 - val_rmse: 4.8593
#
# Epoch 00136: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 137/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 31.6921 - rmse: 5.6296 - val_loss: 24.1052 - val_rmse: 4.9097
#
# Epoch 00137: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 138/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 31.8998 - rmse: 5.6480 - val_loss: 23.7118 - val_rmse: 4.8695
#
# Epoch 00138: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 139/1000
# 70/70 [==============================] - 12s 166ms/step - loss: 34.6533 - rmse: 5.8867 - val_loss: 23.7843 - val_rmse: 4.8769
#
# Epoch 00139: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 140/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 30.4713 - rmse: 5.5201 - val_loss: 26.9142 - val_rmse: 5.1879
#
# Epoch 00140: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 141/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 31.5229 - rmse: 5.6145 - val_loss: 28.3448 - val_rmse: 5.3240
#
# Epoch 00141: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 142/1000
# 70/70 [==============================] - 12s 170ms/step - loss: 30.1980 - rmse: 5.4953 - val_loss: 25.7651 - val_rmse: 5.0759
#
# Epoch 00142: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 143/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 31.5558 - rmse: 5.6175 - val_loss: 25.0835 - val_rmse: 5.0083
#
# Epoch 00143: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 144/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 32.2157 - rmse: 5.6759 - val_loss: 23.4860 - val_rmse: 4.8462
#
# Epoch 00144: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 145/1000
# 70/70 [==============================] - 12s 166ms/step - loss: 32.2760 - rmse: 5.6812 - val_loss: 26.3058 - val_rmse: 5.1289
#
# Epoch 00145: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 146/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 32.9940 - rmse: 5.7440 - val_loss: 24.1404 - val_rmse: 4.9133
#
# Epoch 00146: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 147/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 31.4684 - rmse: 5.6097 - val_loss: 24.8116 - val_rmse: 4.9811
#
# Epoch 00147: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 148/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 31.8850 - rmse: 5.6467 - val_loss: 24.3578 - val_rmse: 4.9354
#
# Epoch 00148: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 149/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 32.3393 - rmse: 5.6868 - val_loss: 25.0301 - val_rmse: 5.0030
#
# Epoch 00149: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 150/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 29.8210 - rmse: 5.4609 - val_loss: 28.0603 - val_rmse: 5.2972
#
# Epoch 00150: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 151/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 32.3329 - rmse: 5.6862 - val_loss: 26.3038 - val_rmse: 5.1287
#
# Epoch 00151: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 152/1000
# 70/70 [==============================] - 12s 170ms/step - loss: 29.7371 - rmse: 5.4532 - val_loss: 23.6727 - val_rmse: 4.8655
#
# Epoch 00152: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 153/1000
# 70/70 [==============================] - 12s 171ms/step - loss: 31.7957 - rmse: 5.6388 - val_loss: 23.3322 - val_rmse: 4.8303
#
# Epoch 00153: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 154/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 31.7766 - rmse: 5.6371 - val_loss: 23.7697 - val_rmse: 4.8754
#
# Epoch 00154: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 155/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 30.3969 - rmse: 5.5133 - val_loss: 25.9375 - val_rmse: 5.0929
#
# Epoch 00155: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 156/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 33.7618 - rmse: 5.8105 - val_loss: 25.0318 - val_rmse: 5.0032
#
# Epoch 00156: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 157/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 32.0812 - rmse: 5.6640 - val_loss: 25.6067 - val_rmse: 5.0603
#
# Epoch 00157: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 158/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 30.6187 - rmse: 5.5334 - val_loss: 24.9487 - val_rmse: 4.9949
#
# Epoch 00158: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 159/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 30.7743 - rmse: 5.5475 - val_loss: 24.5253 - val_rmse: 4.9523
#
# Epoch 00159: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 160/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 32.3967 - rmse: 5.6918 - val_loss: 24.0300 - val_rmse: 4.9020
#
# Epoch 00160: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 161/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 30.2027 - rmse: 5.4957 - val_loss: 24.7090 - val_rmse: 4.9708
#
# Epoch 00161: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 162/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 30.4567 - rmse: 5.5188 - val_loss: 24.5899 - val_rmse: 4.9588
#
# Epoch 00162: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 163/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 30.0112 - rmse: 5.4783 - val_loss: 24.7960 - val_rmse: 4.9796
#
# Epoch 00163: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 164/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 31.4068 - rmse: 5.6042 - val_loss: 25.7389 - val_rmse: 5.0734
#
# Epoch 00164: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 165/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 30.7965 - rmse: 5.5495 - val_loss: 27.2804 - val_rmse: 5.2231
#
# Epoch 00165: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 166/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 30.1524 - rmse: 5.4911 - val_loss: 27.7853 - val_rmse: 5.2712
#
# Epoch 00166: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 167/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 31.7157 - rmse: 5.6317 - val_loss: 24.3365 - val_rmse: 4.9332
#
# Epoch 00167: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 168/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 30.5712 - rmse: 5.5291 - val_loss: 26.9942 - val_rmse: 5.1956
#
# Epoch 00168: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 169/1000
# 70/70 [==============================] - 12s 166ms/step - loss: 31.4675 - rmse: 5.6096 - val_loss: 23.9239 - val_rmse: 4.8912
#
# Epoch 00169: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 170/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 30.8919 - rmse: 5.5581 - val_loss: 30.2107 - val_rmse: 5.4964
#
# Epoch 00170: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 171/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 31.8179 - rmse: 5.6407 - val_loss: 26.4187 - val_rmse: 5.1399
#
# Epoch 00171: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 172/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 31.2017 - rmse: 5.5858 - val_loss: 25.2045 - val_rmse: 5.0204
#
# Epoch 00172: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 173/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 31.4533 - rmse: 5.6083 - val_loss: 26.3256 - val_rmse: 5.1308
#
# Epoch 00173: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 174/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 30.1280 - rmse: 5.4889 - val_loss: 24.4655 - val_rmse: 4.9463
#
# Epoch 00174: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 175/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 31.0012 - rmse: 5.5679 - val_loss: 24.8051 - val_rmse: 4.9805
#
# Epoch 00175: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 176/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 33.4600 - rmse: 5.7845 - val_loss: 25.2010 - val_rmse: 5.0201
#
# Epoch 00176: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 177/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 32.8606 - rmse: 5.7324 - val_loss: 27.9291 - val_rmse: 5.2848
#
# Epoch 00177: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 178/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 30.7301 - rmse: 5.5435 - val_loss: 23.9286 - val_rmse: 4.8917
#
# Epoch 00178: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 179/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 29.9114 - rmse: 5.4691 - val_loss: 24.1932 - val_rmse: 4.9187
#
# Epoch 00179: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 180/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 30.3270 - rmse: 5.5070 - val_loss: 23.1211 - val_rmse: 4.8084
#
# Epoch 00180: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 181/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 32.1043 - rmse: 5.6661 - val_loss: 25.6647 - val_rmse: 5.0660
#
# Epoch 00181: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 182/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 29.8274 - rmse: 5.4614 - val_loss: 26.0417 - val_rmse: 5.1031
#
# Epoch 00182: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 183/1000
# 70/70 [==============================] - 12s 170ms/step - loss: 29.8948 - rmse: 5.4676 - val_loss: 23.6467 - val_rmse: 4.8628
#
# Epoch 00183: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 184/1000
# ...
# Epoch 940/1000
# 70/70 [==============================] - 12s 170ms/step - loss: 28.7939 - rmse: 5.3660 - val_loss: 21.5506 - val_rmse: 4.6423
#
# Epoch 00940: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 941/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 28.6438 - rmse: 5.3520 - val_loss: 21.6146 - val_rmse: 4.6491
#
# Epoch 00941: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 942/1000
# 70/70 [==============================] - 12s 170ms/step - loss: 26.6476 - rmse: 5.1621 - val_loss: 19.6794 - val_rmse: 4.4361
#
# Epoch 00942: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 943/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 26.8089 - rmse: 5.1777 - val_loss: 24.8761 - val_rmse: 4.9876
#
# Epoch 00943: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 944/1000
# 70/70 [==============================] - 12s 170ms/step - loss: 29.4838 - rmse: 5.4299 - val_loss: 20.2830 - val_rmse: 4.5037
#
# Epoch 00944: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 945/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 29.7390 - rmse: 5.4533 - val_loss: 24.7971 - val_rmse: 4.9797
#
# Epoch 00945: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 946/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 28.4196 - rmse: 5.3310 - val_loss: 21.1725 - val_rmse: 4.6014
#
# Epoch 00946: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 947/1000
# 70/70 [==============================] - 12s 170ms/step - loss: 27.6970 - rmse: 5.2628 - val_loss: 24.4108 - val_rmse: 4.9407
#
# Epoch 00947: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 948/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 27.5670 - rmse: 5.2504 - val_loss: 24.4778 - val_rmse: 4.9475
#
# Epoch 00948: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 949/1000
# 70/70 [==============================] - 12s 172ms/step - loss: 27.9784 - rmse: 5.2895 - val_loss: 24.7541 - val_rmse: 4.9753
#
# Epoch 00949: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 950/1000
# 70/70 [==============================] - 12s 170ms/step - loss: 31.2623 - rmse: 5.5913 - val_loss: 20.2981 - val_rmse: 4.5053
#
# Epoch 00950: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 951/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 29.3704 - rmse: 5.4194 - val_loss: 23.9744 - val_rmse: 4.8964
#
# Epoch 00951: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 952/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 28.9305 - rmse: 5.3787 - val_loss: 21.4337 - val_rmse: 4.6297
#
# Epoch 00952: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 953/1000
# 70/70 [==============================] - 12s 170ms/step - loss: 27.8898 - rmse: 5.2811 - val_loss: 25.2617 - val_rmse: 5.0261
#
# Epoch 00953: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 954/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 29.9714 - rmse: 5.4746 - val_loss: 21.0501 - val_rmse: 4.5880
#
# Epoch 00954: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 955/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 28.7596 - rmse: 5.3628 - val_loss: 22.9704 - val_rmse: 4.7927
#
# Epoch 00955: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 956/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 29.6700 - rmse: 5.4470 - val_loss: 24.8602 - val_rmse: 4.9860
#
# Epoch 00956: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 957/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 27.9246 - rmse: 5.2844 - val_loss: 19.9086 - val_rmse: 4.4619
#
# Epoch 00957: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 958/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 28.7403 - rmse: 5.3610 - val_loss: 20.4971 - val_rmse: 4.5274
#
# Epoch 00958: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 959/1000
# 70/70 [==============================] - 12s 171ms/step - loss: 28.7618 - rmse: 5.3630 - val_loss: 20.5940 - val_rmse: 4.5381
#
# Epoch 00959: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 960/1000
# 70/70 [==============================] - 12s 172ms/step - loss: 28.1188 - rmse: 5.3027 - val_loss: 20.2601 - val_rmse: 4.5011
#
# Epoch 00960: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 961/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 29.9427 - rmse: 5.4720 - val_loss: 22.6665 - val_rmse: 4.7609
#
# Epoch 00961: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 962/1000
# 70/70 [==============================] - 12s 170ms/step - loss: 27.8375 - rmse: 5.2761 - val_loss: 21.8987 - val_rmse: 4.6796
#
# Epoch 00962: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 963/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 28.0720 - rmse: 5.2983 - val_loss: 22.6255 - val_rmse: 4.7566
#
# Epoch 00963: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 964/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 28.7226 - rmse: 5.3593 - val_loss: 22.2302 - val_rmse: 4.7149
#
# Epoch 00964: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 965/1000
# 70/70 [==============================] - 12s 170ms/step - loss: 28.0309 - rmse: 5.2944 - val_loss: 26.8731 - val_rmse: 5.1839
#
# Epoch 00965: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 966/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 29.6737 - rmse: 5.4474 - val_loss: 22.9414 - val_rmse: 4.7897
#
# Epoch 00966: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 967/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 27.9239 - rmse: 5.2843 - val_loss: 21.8042 - val_rmse: 4.6695
#
# Epoch 00967: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 968/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 29.6754 - rmse: 5.4475 - val_loss: 25.0821 - val_rmse: 5.0082
#
# Epoch 00968: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 969/1000
# 70/70 [==============================] - 12s 170ms/step - loss: 28.4534 - rmse: 5.3342 - val_loss: 24.4528 - val_rmse: 4.9450
#
# Epoch 00969: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 970/1000
# 70/70 [==============================] - 12s 171ms/step - loss: 27.1656 - rmse: 5.2121 - val_loss: 24.3417 - val_rmse: 4.9337
#
# Epoch 00970: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 971/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 29.9758 - rmse: 5.4750 - val_loss: 23.9462 - val_rmse: 4.8935
#
# Epoch 00971: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 972/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 29.8456 - rmse: 5.4631 - val_loss: 22.5224 - val_rmse: 4.7458
#
# Epoch 00972: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 973/1000
# 70/70 [==============================] - 12s 170ms/step - loss: 27.7342 - rmse: 5.2663 - val_loss: 20.9581 - val_rmse: 4.5780
#
# Epoch 00973: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 974/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 30.3500 - rmse: 5.5091 - val_loss: 24.8187 - val_rmse: 4.9818
#
# Epoch 00974: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 975/1000
# 70/70 [==============================] - 12s 170ms/step - loss: 26.3331 - rmse: 5.1316 - val_loss: 21.7135 - val_rmse: 4.6598
#
# Epoch 00975: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 976/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 27.1933 - rmse: 5.2147 - val_loss: 23.2105 - val_rmse: 4.8177
#
# Epoch 00976: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 977/1000
# 70/70 [==============================] - 12s 170ms/step - loss: 29.3709 - rmse: 5.4195 - val_loss: 20.3639 - val_rmse: 4.5126
#
# Epoch 00977: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 978/1000
# 70/70 [==============================] - 12s 167ms/step - loss: 27.7441 - rmse: 5.2673 - val_loss: 21.3465 - val_rmse: 4.6202
#
# Epoch 00978: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 979/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 27.3591 - rmse: 5.2306 - val_loss: 22.4217 - val_rmse: 4.7352
#
# Epoch 00979: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 980/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 28.0160 - rmse: 5.2930 - val_loss: 25.7515 - val_rmse: 5.0746
#
# Epoch 00980: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 981/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 29.3511 - rmse: 5.4177 - val_loss: 20.8586 - val_rmse: 4.5671
#
# Epoch 00981: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 982/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 28.4322 - rmse: 5.3322 - val_loss: 20.6128 - val_rmse: 4.5401
#
# Epoch 00982: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 983/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 28.0610 - rmse: 5.2973 - val_loss: 20.8382 - val_rmse: 4.5649
#
# Epoch 00983: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 984/1000
# 70/70 [==============================] - 12s 170ms/step - loss: 27.1783 - rmse: 5.2133 - val_loss: 24.4956 - val_rmse: 4.9493
#
# Epoch 00984: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 985/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 28.0670 - rmse: 5.2978 - val_loss: 23.5696 - val_rmse: 4.8548
#
# Epoch 00985: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 986/1000
# 70/70 [==============================] - 12s 170ms/step - loss: 28.9757 - rmse: 5.3829 - val_loss: 24.5366 - val_rmse: 4.9534
#
# Epoch 00986: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 987/1000
# 70/70 [==============================] - 12s 171ms/step - loss: 29.6702 - rmse: 5.4470 - val_loss: 22.3325 - val_rmse: 4.7257
#
# Epoch 00987: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 988/1000
# 70/70 [==============================] - 12s 170ms/step - loss: 29.5794 - rmse: 5.4387 - val_loss: 21.4300 - val_rmse: 4.6293
#
# Epoch 00988: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 989/1000
# 70/70 [==============================] - 12s 170ms/step - loss: 29.7901 - rmse: 5.4580 - val_loss: 22.3710 - val_rmse: 4.7298
#
# Epoch 00989: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 990/1000
# 70/70 [==============================] - 12s 172ms/step - loss: 28.8808 - rmse: 5.3741 - val_loss: 19.6358 - val_rmse: 4.4312
#
# Epoch 00990: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 991/1000
# 70/70 [==============================] - 12s 171ms/step - loss: 28.9977 - rmse: 5.3850 - val_loss: 22.1033 - val_rmse: 4.7014
#
# Epoch 00991: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 992/1000
# 70/70 [==============================] - 12s 170ms/step - loss: 29.0919 - rmse: 5.3937 - val_loss: 23.9028 - val_rmse: 4.8891
#
# Epoch 00992: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 993/1000
# 70/70 [==============================] - 12s 170ms/step - loss: 27.8295 - rmse: 5.2754 - val_loss: 21.6958 - val_rmse: 4.6579
#
# Epoch 00993: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 994/1000
# 70/70 [==============================] - 12s 171ms/step - loss: 29.2718 - rmse: 5.4103 - val_loss: 19.7557 - val_rmse: 4.4447
#
# Epoch 00994: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 995/1000
# 70/70 [==============================] - 12s 171ms/step - loss: 27.2539 - rmse: 5.2205 - val_loss: 23.0164 - val_rmse: 4.7975
#
# Epoch 00995: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 996/1000
# 70/70 [==============================] - 12s 168ms/step - loss: 27.0822 - rmse: 5.2041 - val_loss: 20.7330 - val_rmse: 4.5533
#
# Epoch 00996: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 997/1000
# 70/70 [==============================] - 12s 171ms/step - loss: 28.3208 - rmse: 5.3217 - val_loss: 22.0408 - val_rmse: 4.6948
#
# Epoch 00997: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 998/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 27.6753 - rmse: 5.2607 - val_loss: 20.6646 - val_rmse: 4.5458
#
# Epoch 00998: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 999/1000
# 70/70 [==============================] - 12s 169ms/step - loss: 29.3252 - rmse: 5.4153 - val_loss: 21.4907 - val_rmse: 4.6358
#
# Epoch 00999: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt
# Epoch 1000/1000
# 70/70 [==============================] - 12s 172ms/step - loss: 27.5105 - rmse: 5.2450 - val_loss: 24.5841 - val_rmse: 4.9582
#
# Epoch 01000: saving model to /content/drive/My Drive/Berkeley/W210/Capstone/BERT_Model_Transcription/training_1/cp.ckpt

# %%
metrics = bert_history.history
plt.plot(bert_history.epoch, np.sqrt(metrics['rmse'])*30, np.sqrt(metrics['val_rmse'])*30)
plt.legend(['rmse', 'val_rmse'])
axes = plt.axes()
axes.set_ylim([0, 30])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.

# %% [markdown]
# # Evaluation and prediction based on BERT model

# %%
print("Evaluate on vale data")
results = model.evaluate(val_reviews, y_val, batch_size=64)
print("val rmse:", np.sqrt(results)[0])
# Out:
# Evaluate on vale data
# 5/5 [==============================] - 5s 353ms/step - loss: 54.5263 - rmse: 7.3842
# val rmse: 7.384193250927349

# %%
result = model.predict(train_ds)
result
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/functional.py:595: UserWarning: Input dict contained keys ['attention_mask', 'token_type_ids'] which did not match any model input. They will be ignored by the model.
#   [n for n in tensors.keys() if n not in ref_input_names])
# array([[25.232538],
#        [22.802418],
#        [23.4632  ],
#        ...,
#        [27.085352],
#        [27.006544],
#        [25.301317]], dtype=float32)
